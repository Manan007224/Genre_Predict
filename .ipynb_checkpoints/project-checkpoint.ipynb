# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os, platform, sys
import nltk
from nltk.corpus import stopwords
from sklearn.feature_extraction.text import CountVectorizer,TfidfVectorizer
from sklearn.naive_bayes import GaussianNB,MultinomialNB
from sklearn.svm import SVC
from sklearn import linear_model
from sklearn.preprocessing  import PolynomialFeatures
from sklearn.model_selection import train_test_split
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import LabelEncoder
import seaborn as sns
from sklearn.linear_model import SGDClassifier,LogisticRegression
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler,LabelEncoder,MinMaxScaler
from sklearn.linear_model import LinearRegression
import string
import re
from nltk.corpus import sentiwordnet as swn
import time
import spacy
from sklearn.neighbors import KNeighborsClassifier
import en_core_web_sm

nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\User\Anaconda3\lib\site-packages\nltk...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\User\Anaconda3\lib\site-packages\nltk...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\User\Anaconda3\lib\site-packages\nltk...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
omdb_data = pd.read_json('data/omdb-data.json.gz', orient='records', lines=True)
rotten_tomatoes = pd.read_json('data/rotten-tomatoes.json.gz', orient='records', lines=True)

def change_pdFrame(row, new_df):
   temp_genres = row['omdb_genres']
   counter = 0
   while counter < len(temp_genres):
       movies_row = row
       movies_row['genres'] = temp_genres[counter]
       new_df.append(movies_row)
       print(new_df)
       counter = counter + 1

movies_data = pd.merge(omdb_data, rotten_tomatoes, on=['imdb_id'])
# c = movies_data.columns
# new_df = pd.DataFrame(columns=c)
refined_movies = movies_data.omdb_genres.apply(pd.Series).stack().reset_index(level=1, drop=True).to_frame('omdb_genres')
refined_movies = refined_movies.reset_index()
movies_data = movies_data.reset_index()
#movies_data = pd.merge(refined_movies, movies_data, on=['index'])

movies_data.head()
# Out:
#    index    imdb_id                                        omdb_awards  \
# 0      0  tt0060814     Nominated for 2 Oscars. Another 2 nominations.
# 1      1  tt2379713      Won 1 Oscar. Another 7 wins & 32 nominations.
# 2      2  tt0230575                                                N/A
# 3      3  tt0065988  Nominated for 1 Oscar. Another 5 wins & 8 nomi...
# 4      4  tt1995390                                     2 nominations.
#
#                      omdb_genres  \
# 0          [Drama, History, War]
# 1  [Action, Adventure, Thriller]
# 2               [Comedy, Horror]
# 3     [Adventure, Comedy, Drama]
# 4       [Crime, Drama, Thriller]
#
#                                            omdb_plot  audience_average  \
# 0  In this sprawling, star-laden film, we see the...               3.5
# 1  A cryptic message from the past sends James Bo...               3.5
# 2  The makers of this parody of "Night of the Liv...               3.3
# 3  Jack Crabb is 121 years old as the film begins...               3.8
# 4  When Perry and his girlfriend, Gail, cross pat...               3.2
#
#    audience_percent  audience_ratings  critic_average  critic_percent  \
# 0              72.0            1311.0             6.4            80.0
# 1              61.0          105323.0             6.4            63.0
# 2              57.0             109.0             NaN             NaN
# 3              87.0           17368.0             7.9            96.0
# 4              50.0            7206.0             6.0            72.0
#
#                                   rotten_tomatoes_id
# 0                                 m/is_paris_burning
# 1                                     m/spectre_2015
# 2  m/night_of_the_day_of_the_dawn_of_the_son_of_t...
# 3                                   m/little_big_man
# 4                         m/our_kind_of_traitor_2016

# %%
STOPWORDS = stopwords.words('english')
nlp = en_core_web_sm.load()

def tokenize_text(row,col) : 
    ar = nltk.word_tokenize(row[col])
    return [i.lower() for i in ar]

def remove_stopwords(row,col) : 
    token_set = set(row[col])
    sw_set = set(STOPWORDS)
    return list(token_set.difference(sw_set))

def remove_characters_after_tokenization(tokens):
    pattern = re.compile('[{}]'.format(re.escape(string.punctuation)))
    filtered_tokens = filter(None, [pattern.sub('', token) for token in tokens])
    return filtered_tokens
    
def remove_punct(row,col):
    return list(remove_characters_after_tokenization(row[col]))

def text_purity(row,col_original,col_new) : 
    original_text = len(row[col_original])
    new_text = len(row[col_new])
    return int(new_text)/int(original_text)
    
def stemming(row,col) : 
    stemmer = nltk.stem.WordNetLemmatizer()
    #stemmer = nltk.stem.snowball.PorterStemmer()
    return [stemmer.lemmatize(w) for w in row[col]]
    
def stem_word_count(row,col) : 
    return len(row[col].values.tolist())

def tag_tokens(row,col,tokens=False) : 
    doc = nlp(row[col])
    return [(t.text,t.tag_) for t in doc]

def extract_keyword_weights(row,col,NUM_TOPICS) : 
    sents=row[col]
    print(sents)
    tokens = list(map(lambda x:nltk.word_tokenize(x),sents))
    lsi = train_lsi_model_gensim(tokens,total_topics=NUM_TOPICS)
    parse_weighted_lsi_model(lsi)
    return parse_weighted_lsi_model

def feature_matrix_fit(data,vect_type,data_col) : 
    
    input_data = data[data_col].values
    if vect_type == 'count' : vectorizer = CountVectorizer(min_df=0.0,max_df=1.0,analyzer='word',ngram_range=(1,1))
    elif vect_type == 'tfidf' :   vectorizer = TfidfVectorizer(min_df=0.0,max_df=1.0,analyzer='word',ngram_range=(1,1))   
    features = vectorizer.fit_transform(input_data)
    return vectorizer,features

dataset = movies_data[['audience_percent', 'omdb_plot']]



dataset['tokens'] = dataset.apply(tokenize_text, args=('omdb_plot', ), axis=1)
dataset['tokens'] = dataset.apply(remove_punct,args=('tokens',),axis=1)
dataset['token_string'] = dataset.apply(lambda x:' '.join(x['tokens']),axis=1)
dataset['no_sw'] = dataset.apply(remove_stopwords,args=('tokens',),axis=1)
dataset['purity'] = dataset.apply(text_purity,args=('tokens','no_sw',),axis=1)
dataset['no_sw_string'] = dataset.apply(lambda x:' '.join(x['no_sw']),axis=1)
dataset['stemmed'] = dataset.apply(stemming,args=('no_sw',),axis=1)
dataset['wc_stemmed'] = dataset.apply(lambda x:len(x['stemmed']),axis=1)
dataset['stemmed_string'] = dataset.apply(lambda x:' '.join(x['stemmed']),axis=1)
# Out:
# C:\Users\User\Anaconda3\lib\site-packages\ipykernel_launcher.py:58: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\User\Anaconda3\lib\site-packages\ipykernel_launcher.py:59: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\User\Anaconda3\lib\site-packages\ipykernel_launcher.py:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\User\Anaconda3\lib\site-packages\ipykernel_launcher.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\User\Anaconda3\lib\site-packages\ipykernel_launcher.py:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\User\Anaconda3\lib\site-packages\ipykernel_launcher.py:63: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\User\Anaconda3\lib\site-packages\ipykernel_launcher.py:64: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\User\Anaconda3\lib\site-packages\ipykernel_launcher.py:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\User\Anaconda3\lib\site-packages\ipykernel_launcher.py:66: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
scaler = MinMaxScaler(feature_range=(0,1))
wc_stemmed_feature = scaler.fit_transform(dataset['wc_stemmed'].values.reshape(-1,1))
dataset['wc_stemmed_scaled'] = wc_stemmed_feature
# Out:
# C:\Users\User\Anaconda3\lib\site-packages\sklearn\utils\validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by MinMaxScaler.
#   warnings.warn(msg, DataConversionWarning)

# %%
dataset = dataset.dropna()
dataset
# Out:
#       audience_percent                                          omdb_plot  \
# 0                 72.0  In this sprawling, star-laden film, we see the...
# 1                 61.0  A cryptic message from the past sends James Bo...
# 2                 57.0  The makers of this parody of "Night of the Liv...
# 3                 87.0  Jack Crabb is 121 years old as the film begins...
# 4                 50.0  When Perry and his girlfriend, Gail, cross pat...
# 5                 93.0  Protagonist Alex DeLarge is an "ultraviolent" ...
# 6                 54.0  Captain Jack Sparrow (Depp) crosses paths with...
# 7                 88.0  It is the early 60s in France. The remaining s...
# 8                 75.0  On July 2nd, communications systems worldwide ...
# 9                 94.0  Paranoid Brigadier General Jack D. Ripper of B...
# 10                86.0  This English-language adaptation of the Swedis...
# 11                92.0  England's Prince Albert must ascend the throne...
# 12                95.0  An ancient Ring thought lost for centuries has...
# 13                71.0  Depicting the events after the Gamma Bomb. 'Th...
# 14                62.0  English rock star Aldous Snow relapses into dr...
# 15                83.0  Tony Stark creates the Ultron Program to prote...
# 16                76.0  Benjamin Franklin Gates descends from a family...
# 17                83.0  James Bond 007 is on the search for a Russian ...
# 18                91.0  Tony Stark. Genius, billionaire, playboy, phil...
# 19                87.0  CIA chief Hunley (Baldwin) convinces a Senate ...
# 20                90.0  Tells the story of Evey Hammond and her unlike...
# 21                72.0  Life for former United Nations investigator Ge...
# 22                82.0  This is the tale of Harry Potter, an ordinary ...
# 23                68.0  Robert Neville is a scientist who was unable t...
# 24                66.0  The pilot of a rescue copter, Captain Karen Wa...
# 25                58.0  The events in this movie take place around the...
# 26                47.0  It was supposed to be a simple job. All Lucy h...
# 27                72.0  Once again we're plunged into the world of swo...
# 28                95.0  FBI trainee Clarice Starling works hard to adv...
# 29                64.0  George Lazenby steps into the role of James Bo...
# ...                ...                                                ...
# 9583              55.0  The action takes place shortly after the end o...
# 9584              84.0  In the Town of Derry, the local kids are disap...
# 9585               7.0  A hardboiled aging private eye is hired to fin...
# 9586               8.0  A writer returns to Hollywood after finishing ...
# 9588              24.0  Ineffectual, 'has-been' film-maker (Dennis Qua...
# 9590              53.0  In a dystopian future, two rival gangs fight f...
# 9591              75.0  Film is a collection of several interlinked st...
# 9592               0.0  A retired Diplomat and an NYPD Detective seeki...
# 9593              41.0  Helena is a young girl who spent all her life ...
# 9594              59.0  When detective Eric Matthews is called to a cr...
# 9596              61.0  Pepe Le Moko, a thief who escaped from France ...
# 9597              23.0  A dark comedy about three salesmen from Detroi...
# 9598              84.0  Waking up in a undisclosed location in a unkno...
# 9599              35.0       Two black brothers send back to slavery time
# 9600              41.0  When their attempt to rob a casino owned by th...
# 9603              72.0  The story of Oscar Wilde, genius, poet, playwr...
# 9604              67.0  A rediscovered classic from director Ken Loach...
# 9606              49.0  Estelle is a one-person protest army: she goes...
# 9607              58.0  In WW2, after a tank battle, a wounded Soviet ...
# 9608              70.0  A young woman is in Orlando visiting her ailin...
# 9609              40.0  Alex Rose and Nancy Kendricks are a young coup...
# 9611              63.0  Nicklas lives a pretty normal teenage life, un...
# 9613              81.0  An acerbic radio talk show host based in Dalla...
# 9614              17.0  "Season of the Equinox, the witch besets her k...
# 9616              69.0  This movie features the collaborative director...
# 9617              73.0  Einar and Eric are two Viking half-brothers. T...
# 9618              62.0  In lieu of love and affections from his multi-...
# 9619              88.0  Competitive ice skater Tonya Harding rises amo...
# 9620              91.0  Plot: Bwakaw is a drama-comedy about growing o...
# 9621              16.0  A military family takes part in a ground-break...
#
#                                                  tokens  \
# 0     [in, this, sprawling, starladen, film, we, see...
# 1     [a, cryptic, message, from, the, past, sends, ...
# 2     [the, makers, of, this, parody, of, night, of,...
# 3     [jack, crabb, is, 121, years, old, as, the, fi...
# 4     [when, perry, and, his, girlfriend, gail, cros...
# 5     [protagonist, alex, delarge, is, an, ultraviol...
# 6     [captain, jack, sparrow, depp, crosses, paths,...
# 7     [it, is, the, early, 60s, in, france, the, rem...
# 8     [on, july, 2nd, communications, systems, world...
# 9     [paranoid, brigadier, general, jack, d, ripper...
# 10    [this, englishlanguage, adaptation, of, the, s...
# 11    [england, s, prince, albert, must, ascend, the...
# 12    [an, ancient, ring, thought, lost, for, centur...
# 13    [depicting, the, events, after, the, gamma, bo...
# 14    [english, rock, star, aldous, snow, relapses, ...
# 15    [tony, stark, creates, the, ultron, program, t...
# 16    [benjamin, franklin, gates, descends, from, a,...
# 17    [james, bond, 007, is, on, the, search, for, a...
# 18    [tony, stark, genius, billionaire, playboy, ph...
# 19    [cia, chief, hunley, baldwin, convinces, a, se...
# 20    [tells, the, story, of, evey, hammond, and, he...
# 21    [life, for, former, united, nations, investiga...
# 22    [this, is, the, tale, of, harry, potter, an, o...
# 23    [robert, neville, is, a, scientist, who, was, ...
# 24    [the, pilot, of, a, rescue, copter, captain, k...
# 25    [the, events, in, this, movie, take, place, ar...
# 26    [it, was, supposed, to, be, a, simple, job, al...
# 27    [once, again, we, re, plunged, into, the, worl...
# 28    [fbi, trainee, clarice, starling, works, hard,...
# 29    [george, lazenby, steps, into, the, role, of, ...
# ...                                                 ...
# 9583  [the, action, takes, place, shortly, after, th...
# 9584  [in, the, town, of, derry, the, local, kids, a...
# 9585  [a, hardboiled, aging, private, eye, is, hired...
# 9586  [a, writer, returns, to, hollywood, after, fin...
# 9588  [ineffectual, hasbeen, filmmaker, dennis, quai...
# 9590  [in, a, dystopian, future, two, rival, gangs, ...
# 9591  [film, is, a, collection, of, several, interli...
# 9592  [a, retired, diplomat, and, an, nypd, detectiv...
# 9593  [helena, is, a, young, girl, who, spent, all, ...
# 9594  [when, detective, eric, matthews, is, called, ...
# 9596  [pepe, le, moko, a, thief, who, escaped, from,...
# 9597  [a, dark, comedy, about, three, salesmen, from...
# 9598  [waking, up, in, a, undisclosed, location, in,...
# 9599  [two, black, brothers, send, back, to, slavery...
# 9600  [when, their, attempt, to, rob, a, casino, own...
# 9603  [the, story, of, oscar, wilde, genius, poet, p...
# 9604  [a, rediscovered, classic, from, director, ken...
# 9606  [estelle, is, a, oneperson, protest, army, she...
# 9607  [in, ww2, after, a, tank, battle, a, wounded, ...
# 9608  [a, young, woman, is, in, orlando, visiting, h...
# 9609  [alex, rose, and, nancy, kendricks, are, a, yo...
# 9611  [nicklas, lives, a, pretty, normal, teenage, l...
# 9613  [an, acerbic, radio, talk, show, host, based, ...
# 9614  [season, of, the, equinox, the, witch, besets,...
# 9616  [this, movie, features, the, collaborative, di...
# 9617  [einar, and, eric, are, two, viking, halfbroth...
# 9618  [in, lieu, of, love, and, affections, from, hi...
# 9619  [competitive, ice, skater, tonya, harding, ris...
# 9620  [plot, bwakaw, is, a, dramacomedy, about, grow...
# 9621  [a, military, family, takes, part, in, a, grou...
#
#                                            token_string  \
# 0     in this sprawling starladen film we see the st...
# 1     a cryptic message from the past sends james bo...
# 2     the makers of this parody of night of the livi...
# 3     jack crabb is 121 years old as the film begins...
# 4     when perry and his girlfriend gail cross paths...
# 5     protagonist alex delarge is an ultraviolent yo...
# 6     captain jack sparrow depp crosses paths with a...
# 7     it is the early 60s in france the remaining su...
# 8     on july 2nd communications systems worldwide a...
# 9     paranoid brigadier general jack d ripper of bu...
# 10    this englishlanguage adaptation of the swedish...
# 11    england s prince albert must ascend the throne...
# 12    an ancient ring thought lost for centuries has...
# 13    depicting the events after the gamma bomb the ...
# 14    english rock star aldous snow relapses into dr...
# 15    tony stark creates the ultron program to prote...
# 16    benjamin franklin gates descends from a family...
# 17    james bond 007 is on the search for a russian ...
# 18    tony stark genius billionaire playboy philanth...
# 19    cia chief hunley baldwin convinces a senate co...
# 20    tells the story of evey hammond and her unlike...
# 21    life for former united nations investigator ge...
# 22    this is the tale of harry potter an ordinary 1...
# 23    robert neville is a scientist who was unable t...
# 24    the pilot of a rescue copter captain karen wal...
# 25    the events in this movie take place around the...
# 26    it was supposed to be a simple job all lucy ha...
# 27    once again we re plunged into the world of swo...
# 28    fbi trainee clarice starling works hard to adv...
# 29    george lazenby steps into the role of james bo...
# ...                                                 ...
# 9583  the action takes place shortly after the end o...
# 9584  in the town of derry the local kids are disapp...
# 9585  a hardboiled aging private eye is hired to fin...
# 9586  a writer returns to hollywood after finishing ...
# 9588  ineffectual hasbeen filmmaker dennis quaid swi...
# 9590  in a dystopian future two rival gangs fight fo...
# 9591  film is a collection of several interlinked st...
# 9592  a retired diplomat and an nypd detective seeki...
# 9593  helena is a young girl who spent all her life ...
# 9594  when detective eric matthews is called to a cr...
# 9596  pepe le moko a thief who escaped from france w...
# 9597  a dark comedy about three salesmen from detroi...
# 9598  waking up in a undisclosed location in a unkno...
# 9599       two black brothers send back to slavery time
# 9600  when their attempt to rob a casino owned by th...
# 9603  the story of oscar wilde genius poet playwrigh...
# 9604  a rediscovered classic from director ken loach...
# 9606  estelle is a oneperson protest army she goes t...
# 9607  in ww2 after a tank battle a wounded soviet ta...
# 9608  a young woman is in orlando visiting her ailin...
# 9609  alex rose and nancy kendricks are a young coup...
# 9611  nicklas lives a pretty normal teenage life unt...
# 9613  an acerbic radio talk show host based in dalla...
# 9614  season of the equinox the witch besets her kil...
# 9616  this movie features the collaborative director...
# 9617  einar and eric are two viking halfbrothers the...
# 9618  in lieu of love and affections from his multim...
# 9619  competitive ice skater tonya harding rises amo...
# 9620  plot bwakaw is a dramacomedy about growing old...
# 9621  a military family takes part in a groundbreaki...
#
#                                                   no_sw    purity  \
# 0     [swedish, centers, resistance, city, charge, l...  0.505882
# 1     [assassin, meets, relevance, james, covertly, ...  0.513889
# 2     [living, george, took, dialogue, night, redubb...  0.555556
# 3     [recounts, oral, asks, old, armstrong, jack, c...  0.576923
# 4     [begin, london, mafia, whose, safe, city, inte...  0.463235
# 5     [creating, luck, prison, eventually, convicts,...  0.388889
# 6     [using, cruz, depp, know, finds, jack, adventu...  0.421687
# 7     [kill, degaulle, million, watch, attempts, fai...  0.477876
# 8     [aliens, attempts, number, 2nd, well, survivor...  0.491124
# 9     [held, chair, work, jack, dismayed, american, ...  0.448980
# 10    [daniel, mara, swedish, englishlanguage, work,...  0.626866
# 11    [country, vi, able, england, logue, elizabeth,...  0.579710
# 12    [forests, reign, lord, cracks, order, ancient,...  0.472441
# 13    [turn, whilst, run, depicting, close, banner, ...  0.507692
# 14    [finish, moderate, gives, ends, day, wants, th...  0.512821
# 15    [tony, try, creates, avengers, impossible, ult...  0.553191
# 16    [revolutionary, treasureseekers, founding, che...  0.469388
# 17    [james, tricks, decoding, whilst, books, sneak...  0.567901
# 18    [primitive, weapons, badly, unit, james, home,...  0.464968
# 19    [impossible, chief, hunley, mission, rogue, re...  0.541667
# 20    [fascist, time, taken, led, lifeanddeath, gene...  0.450000
# 21    [rampaging, turning, escaping, answers, lane, ...  0.611111
# 22    [makes, dangerous, wizardry, wizard, finds, 11...  0.429752
# 23    [using, move, best, left, time, unable, city, ...  0.462687
# 24    [iraqis, held, crashed, colonel, medal, whethe...  0.427083
# 25    [ops, involved, kill, affect, marta, time, med...  0.366972
# 26    [briefcase, undergoes, powerful, leaks, nightm...  0.508929
# 27    [complicated, sentenced, unless, compass, hell...  0.474747
# 28    [opportunist, scrutiny, especially, work, jack...  0.444444
# 29    [lazenby, longer, stavro, irma, james, hilary,...  0.480000
# ...                                                 ...       ...
# 9583  [personal, shellshocked, seem, place, warrior,...  0.533333
# 9584  [kill, seven, place, strange, kids, bloody, ev...  0.489362
# 9585  [even, sought, hardboiled, find, gangsters, be...  0.534884
# 9586  [violent, involved, girlfriend, eventually, bo...  0.492537
# 9588  [peerpressuring, isolated, seducing, dejected,...  0.529851
# 9590  [meth, dystopian, purposes, become, competitiv...  0.600000
# 9591  [interlinked, film, happen, collection, severa...  0.562500
# 9592  [nypd, market, wounded, dealer, psychotic, bla...  0.528302
# 9593  [experiment, well, connivance, fathers, space,...  0.395455
# 9594  [daniel, nerve, place, matthews, jigsaw, finds...  0.450549
# 9596  [meets, especially, prison, impenetrable, esca...  0.571429
# 9597  [involved, fun, salesmen, comedy, detroit, los...  0.571429
# 9598  [done, random, waking, serial, jigsaw, work, h...  0.442105
# 9599  [two, time, brothers, slavery, back, black, send]  0.875000
# 9600  [pope, 657, city, foot, awry, forced, attempt,...  0.605263
# 9603  [sentenced, douglas, modern, country, oscar, h...  0.586667
# 9604  [wind, photography, garfield, kes, traveling, ...  0.568807
# 9606  [meets, fire, films, tracks, market, avenue, p...  0.519380
# 9607  [ww2, unit, said, severe, tiger, best, taken, ...  0.383562
# 9608  [owner, steals, inventory, state, refuge, orla...  0.490566
# 9609  [believe, move, home, staying, try, tenant, na...  0.492063
# 9611  [done, attention, book, day, throws, life, nex...  0.415842
# 9613  [important, try, love, nationwide, life, radio...  0.409091
# 9614  [supposedly, consume, know, discover, bedroom,...  0.460526
# 9616  [watch, using, slapstick, hard, time, old, end...  0.511278
# 9617  [whilst, halfbrothers, involving, einar, warri...  0.500000
# 9618  [phoolchand, scuffs, opportunity, completed, u...  0.487805
# 9619  [championships, activity, ranks, future, throw...  0.620690
# 9620  [came, bwakaw, man, old, plot, closet, growing...  0.517241
# 9621  [family, experiment, groundbreaking, part, exp...  0.666667
#
#                                            no_sw_string  \
# 0     swedish centers resistance city charge leaders...
# 1     assassin meets relevance james covertly eventu...
# 2     living george took dialogue night redubbed par...
# 3     recounts oral asks old armstrong jack collecto...
# 4     begin london mafia whose safe city intelligenc...
# 5     creating luck prison eventually convicts delar...
# 6     using cruz depp know finds jack adventure love...
# 7     kill degaulle million watch attempts fail pres...
# 8     aliens attempts number 2nd well survivors inte...
# 9     held chair work jack dismayed american codes m...
# 10    daniel mara swedish englishlanguage work blomk...
# 11    country vi able england logue elizabeth develo...
# 12    forests reign lord cracks order ancient fellow...
# 13    turn whilst run depicting close banner unique ...
# 14    finish moderate gives ends day wants things co...
# 15    tony try creates avengers impossible ultron be...
# 16    revolutionary treasureseekers founding chest c...
# 17    james tricks decoding whilst books sneaks poss...
# 18    primitive weapons badly unit james home attack...
# 19    impossible chief hunley mission rogue reckless...
# 20    fascist time taken led lifeanddeath general un...
# 21    rampaging turning escaping answers lane infect...
# 22    makes dangerous wizardry wizard finds 11yearol...
# 23    using move best left time unable city survivor...
# 24    iraqis held crashed colonel medal whether lt d...
# 25    ops involved kill affect marta time medication...
# 26    briefcase undergoes powerful leaks nightmarish...
# 27    complicated sentenced unless compass hell lord...
# 28    opportunist scrutiny especially work jack buff...
# 29    lazenby longer stavro irma james hilary time w...
# ...                                                 ...
# 9583  personal shellshocked seem place warrior becom...
# 9584  kill seven place strange kids bloody evil loca...
# 9585  even sought hardboiled find gangsters beautifu...
# 9586  violent involved girlfriend eventually book fi...
# 9588  peerpressuring isolated seducing dejected boyf...
# 9590  meth dystopian purposes become competitive inh...
# 9591  interlinked film happen collection several yea...
# 9592  nypd market wounded dealer psychotic black pur...
# 9593  experiment well connivance fathers space still...
# 9594  daniel nerve place matthews jigsaw finds antid...
# 9596  meets especially prison impenetrable escaped t...
# 9597  involved fun salesmen comedy detroit los secre...
# 9598  done random waking serial jigsaw work hidnen t...
# 9599          two time brothers slavery back black send
# 9600  pope 657 city foot awry forced attempt passeng...
# 9603  sentenced douglas modern country oscar hard lo...
# 9604  wind photography garfield kes traveling classi...
# 9606  meets fire films tracks market avenue paparazz...
# 9607  ww2 unit said severe tiger best taken battlefi...
# 9608  owner steals inventory state refuge orlando he...
# 9609  believe move home staying try tenant nancy bec...
# 9611  done attention book day throws life next notic...
# 9613  important try love nationwide life radio group...
# 9614  supposedly consume know discover bedroom diffe...
# 9616  watch using slapstick hard time old ends reall...
# 9617  whilst halfbrothers involving einar warrior ta...
# 9618  phoolchand scuffs opportunity completed utiliz...
# 9619  championships activity ranks future thrown ska...
# 9620  came bwakaw man old plot closet growing gay 70...
# 9621  family experiment groundbreaking part explorat...
#
#                                                 stemmed  wc_stemmed  \
# 0     [swedish, center, resistance, city, charge, le...          43
# 1     [assassin, meet, relevance, james, covertly, e...          74
# 2     [living, george, took, dialogue, night, redubb...          15
# 3     [recount, oral, asks, old, armstrong, jack, co...          30
# 4     [begin, london, mafia, whose, safe, city, inte...          63
# 5     [creating, luck, prison, eventually, convict, ...          35
# 6     [using, cruz, depp, know, find, jack, adventur...          35
# 7     [kill, degaulle, million, watch, attempt, fail...          54
# 8     [alien, attempt, number, 2nd, well, survivor, ...          83
# 9     [held, chair, work, jack, dismayed, american, ...         132
# 10    [daniel, mara, swedish, englishlanguage, work,...          42
# 11    [country, vi, able, england, logue, elizabeth,...          40
# 12    [forest, reign, lord, crack, order, ancient, f...          60
# 13    [turn, whilst, run, depicting, close, banner, ...          33
# 14    [finish, moderate, give, end, day, want, thing...          60
# 15    [tony, try, creates, avenger, impossible, ultr...          26
# 16    [revolutionary, treasureseekers, founding, che...          23
# 17    [james, trick, decoding, whilst, book, sneak, ...          46
# 18    [primitive, weapon, badly, unit, james, home, ...          73
# 19    [impossible, chief, hunley, mission, rogue, re...          26
# 20    [fascist, time, taken, led, lifeanddeath, gene...          36
# 21    [rampaging, turning, escaping, answer, lane, i...          44
# 22    [make, dangerous, wizardry, wizard, find, 11ye...          52
# 23    [using, move, best, left, time, unable, city, ...          62
# 24    [iraqi, held, crashed, colonel, medal, whether...          41
# 25    [ops, involved, kill, affect, marta, time, med...          80
# 26    [briefcase, undergoes, powerful, leak, nightma...          57
# 27    [complicated, sentenced, unless, compass, hell...          47
# 28    [opportunist, scrutiny, especially, work, jack...         156
# 29    [lazenby, longer, stavro, irma, james, hilary,...          48
# ...                                                 ...         ...
# 9583  [personal, shellshocked, seem, place, warrior,...          64
# 9584  [kill, seven, place, strange, kid, bloody, evi...          23
# 9585  [even, sought, hardboiled, find, gangster, bea...          23
# 9586  [violent, involved, girlfriend, eventually, bo...          33
# 9588  [peerpressuring, isolated, seducing, dejected,...          71
# 9590  [meth, dystopian, purpose, become, competitive...          45
# 9591  [interlinked, film, happen, collection, severa...           9
# 9592  [nypd, market, wounded, dealer, psychotic, bla...          28
# 9593  [experiment, well, connivance, father, space, ...          87
# 9594  [daniel, nerve, place, matthew, jigsaw, find, ...          41
# 9596  [meet, especially, prison, impenetrable, escap...          52
# 9597  [involved, fun, salesman, comedy, detroit, los...          24
# 9598  [done, random, waking, serial, jigsaw, work, h...          42
# 9599   [two, time, brother, slavery, back, black, send]           7
# 9600  [pope, 657, city, foot, awry, forced, attempt,...          23
# 9603  [sentenced, douglas, modern, country, oscar, h...          44
# 9604  [wind, photography, garfield, kes, traveling, ...          62
# 9606  [meet, fire, film, track, market, avenue, papa...          67
# 9607  [ww2, unit, said, severe, tiger, best, taken, ...          56
# 9608  [owner, steal, inventory, state, refuge, orlan...          26
# 9609  [believe, move, home, staying, try, tenant, na...          31
# 9611  [done, attention, book, day, throw, life, next...          42
# 9613  [important, try, love, nationwide, life, radio...          36
# 9614  [supposedly, consume, know, discover, bedroom,...         105
# 9616  [watch, using, slapstick, hard, time, old, end...          68
# 9617  [whilst, halfbrothers, involving, einar, warri...          31
# 9618  [phoolchand, scuff, opportunity, completed, ut...          40
# 9619  [championship, activity, rank, future, thrown,...          18
# 9620  [came, bwakaw, man, old, plot, closet, growing...          15
# 9621  [family, experiment, groundbreaking, part, exp...          10
#
#                                          stemmed_string  wc_stemmed_scaled
# 0     swedish center resistance city charge leader v...           0.103704
# 1     assassin meet relevance james covertly eventua...           0.180247
# 2     living george took dialogue night redubbed par...           0.034568
# 3     recount oral asks old armstrong jack collector...           0.071605
# 4     begin london mafia whose safe city intelligenc...           0.153086
# 5     creating luck prison eventually convict delarg...           0.083951
# 6     using cruz depp know find jack adventure love ...           0.083951
# 7     kill degaulle million watch attempt fail presi...           0.130864
# 8     alien attempt number 2nd well survivor interfe...           0.202469
# 9     held chair work jack dismayed american code me...           0.323457
# 10    daniel mara swedish englishlanguage work blomk...           0.101235
# 11    country vi able england logue elizabeth develo...           0.096296
# 12    forest reign lord crack order ancient fellowsh...           0.145679
# 13    turn whilst run depicting close banner unique ...           0.079012
# 14    finish moderate give end day want thing concer...           0.145679
# 15    tony try creates avenger impossible ultron bec...           0.061728
# 16    revolutionary treasureseekers founding chest c...           0.054321
# 17    james trick decoding whilst book sneak posse g...           0.111111
# 18    primitive weapon badly unit james home attacke...           0.177778
# 19    impossible chief hunley mission rogue reckless...           0.061728
# 20    fascist time taken led lifeanddeath general un...           0.086420
# 21    rampaging turning escaping answer lane infecti...           0.106173
# 22    make dangerous wizardry wizard find 11yearold ...           0.125926
# 23    using move best left time unable city survivor...           0.150617
# 24    iraqi held crashed colonel medal whether lt di...           0.098765
# 25    ops involved kill affect marta time medication...           0.195062
# 26    briefcase undergoes powerful leak nightmarish ...           0.138272
# 27    complicated sentenced unless compass hell lord...           0.113580
# 28    opportunist scrutiny especially work jack buff...           0.382716
# 29    lazenby longer stavro irma james hilary time w...           0.116049
# ...                                                 ...                ...
# 9583  personal shellshocked seem place warrior becom...           0.155556
# 9584  kill seven place strange kid bloody evil local...           0.054321
# 9585  even sought hardboiled find gangster beautiful...           0.054321
# 9586  violent involved girlfriend eventually book fi...           0.079012
# 9588  peerpressuring isolated seducing dejected boyf...           0.172840
# 9590  meth dystopian purpose become competitive inha...           0.108642
# 9591  interlinked film happen collection several yea...           0.019753
# 9592  nypd market wounded dealer psychotic black pur...           0.066667
# 9593  experiment well connivance father space still ...           0.212346
# 9594  daniel nerve place matthew jigsaw find antidot...           0.098765
# 9596  meet especially prison impenetrable escaped ti...           0.125926
# 9597  involved fun salesman comedy detroit los secre...           0.056790
# 9598  done random waking serial jigsaw work hidnen t...           0.101235
# 9599           two time brother slavery back black send           0.014815
# 9600  pope 657 city foot awry forced attempt passeng...           0.054321
# 9603  sentenced douglas modern country oscar hard lo...           0.106173
# 9604  wind photography garfield kes traveling classi...           0.150617
# 9606  meet fire film track market avenue paparazzo s...           0.162963
# 9607  ww2 unit said severe tiger best taken battlefi...           0.135802
# 9608  owner steal inventory state refuge orlando hea...           0.061728
# 9609  believe move home staying try tenant nancy bec...           0.074074
# 9611  done attention book day throw life next notice...           0.101235
# 9613  important try love nationwide life radio group...           0.086420
# 9614  supposedly consume know discover bedroom diffe...           0.256790
# 9616  watch using slapstick hard time old end really...           0.165432
# 9617  whilst halfbrothers involving einar warrior ta...           0.074074
# 9618  phoolchand scuff opportunity completed utilize...           0.096296
# 9619  championship activity rank future thrown skati...           0.041975
# 9620  came bwakaw man old plot closet growing gay 70...           0.034568
# 9621  family experiment groundbreaking part explorat...           0.022222
#
# [8755 rows x 11 columns]

# %%
## REMOVING OUTLIERS
train_data = dataset
vect,train_features = feature_matrix_fit(train_data,vect_type='count',data_col='stemmed_string')

## MANUALLY ADDING FEATURES

print(train_features.shape)
print(train_data['wc_stemmed_scaled'].shape)

train_features = np.append(train_features.toarray(),train_data['wc_stemmed_scaled'].values.reshape(-1,1),axis=1)
train_features = np.append(train_features,train_data['purity'].values.reshape(-1,1),axis=1)

train_labels = train_data['audience_percent']
xtrain, xtest, ytrain, ytest = train_test_split(train_features,train_labels)
# Out:
# (8755, 37907)
# (8755,)

# %%
print(xtrain.shape)
print(ytrain.shape)
# Out:
# (6566, 37909)
# (6566,)

# %%
model = make_pipeline(PolynomialFeatures(3), Ridge())
model.fit(xtrain, ytrain)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-146-011f685270af> in <module>()
# ----> 1 model = make_pipeline(PolynomialFeatures(degree), Ridge())
#       2 model.fit(xtrain, ytrain)
#
# NameError: name 'degree' is not defined

# %%
model = LinearRegression()
model.fit(xtrain, ytrain)
model.score(xtest, ytest)
# Out:
# -3.2175598831046557e+25

# %%
a=pd.DataFrame(np.array(encoder.inverse_transform(dataset['omdb_genres_x'])))
a[0].unique()
# Out:
# C:\Users\User\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# array(['Drama', 'History', 'War', 'Action', 'Adventure', 'Thriller',
#        'Comedy', 'Horror', 'Crime', 'Sci-Fi', 'Fantasy', 'Mystery',
#        'Biography', 'Music', 'Family', 'Musical', 'Romance', 'Animation',
#        'Documentary', 'Short', 'Sport', 'N/A', 'Western', 'News',
#        'Film-Noir', 'Adult'], dtype=object)

# %%
movies_data['omdb_genres_y'].apply(lambda x:str(x)).value_counts()
# Out:
# ['Comedy', 'Drama', 'Romance']          1032
# ['Drama', 'Romance']                     672
# ['Comedy', 'Drama']                      584
# ['Action', 'Crime', 'Drama']             576
# ['Drama']                                492
# ['Animation', 'Adventure', 'Comedy']     450
# ['Crime', 'Drama', 'Thriller']           432
# ['Action', 'Adventure', 'Comedy']        381
# ['Action', 'Adventure', 'Sci-Fi']        366
# ['Comedy', 'Romance']                    364
# ['Crime', 'Drama', 'Mystery']            336
# ['Action', 'Comedy', 'Crime']            315
# ['Comedy']                               313
# ['Action', 'Adventure', 'Fantasy']       309
# ['Documentary']                          308
# ['Biography', 'Drama', 'History']        285
# ['Action', 'Adventure', 'Drama']         267
# ['Action', 'Crime', 'Thriller']          267
# ['Crime', 'Drama']                       250
# ['Comedy', 'Crime', 'Drama']             240
# ['Horror', 'Thriller']                   226
# ['Animation', 'Action', 'Adventure']     219
# ['Drama', 'Thriller']                    188
# ['Adventure', 'Comedy', 'Family']        183
# ['Animation', 'Adventure', 'Family']     183
# ['Horror']                               182
# ['Biography', 'Crime', 'Drama']          180
# ['Horror', 'Mystery', 'Thriller']        174
# ['Action', 'Adventure', 'Thriller']      168
# ['Adventure', 'Family', 'Fantasy']       165
#                                         ...
# ['Fantasy', 'Romance']                     2
# ['Thriller', 'Drama']                      2
# ['Comedy', 'Action']                       2
# ['Western', 'Comedy']                      2
# ['Western', 'Drama']                       2
# ['Adventure', 'War']                       2
# ['Adventure', 'Mystery']                   2
# ['Family', 'Short']                        2
# ['Documentary', 'Animation']               2
# ['Adult', 'Horror']                        2
# ['Romance', 'Sci-Fi']                      2
# ['Short', 'Sci-Fi']                        2
# ['Drama', 'Short']                         2
# ['Documentary', 'Romance']                 2
# ['Crime', 'Comedy']                        2
# ['War', 'Comedy']                          2
# ['Musical', 'Drama']                       2
# ['Adventure', 'Thriller']                  2
# ['Horror', 'Fantasy']                      2
# ['War', 'Western']                         2
# ['Mystery', 'Romance']                     2
# ['Drama', 'Adventure']                     2
# ['Documentary', 'Thriller']                2
# ['Film-Noir', 'Thriller']                  2
# ['Fantasy', 'Mystery']                     2
# ['Crime', 'Family']                        2
# ['Action', 'Romance']                      2
# ['Short']                                  1
# ['Biography']                              1
# ['War']                                    1
# Name: omdb_genres_y, Length: 716, dtype: int64
